# %%
import boto3
import json
import time
from datetime import datetime

# Initialize the Lambda client
lambda_client = boto3.client('lambda')

# Lambda function name
function_name = 'etl_fetch_raw_taxi_data'

# Parameters
year = 2023
bucket_name = 'jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702'
s3_key_prefix = 'taxi/raw'
glue_job_name = 'etl-taxi-filter-and-transform'

# Create a timestamp for logging
timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Starting Lambda invocations at {timestamp}")

# Loop through all months of 2024
for month in range(1, 13):
    # Create the payload for the Lambda function
    payload = {
        'year': year,
        'month': month,
        'bucket_name': bucket_name,
        's3_key_prefix': s3_key_prefix,
        'glue_job_name': glue_job_name
    }

    print(f"\nInvoking Lambda for {year}-{month:02d}...")

    try:
        # Invoke the Lambda function
        response = lambda_client.invoke(
            FunctionName=function_name,
            InvocationType='RequestResponse',  # Use 'Event' for asynchronous invocation
            Payload=json.dumps(payload)
        )

        # Parse the response
        response_payload = json.loads(response['Payload'].read().decode())

        # Print the response
        print(f"Status code: {response['StatusCode']}")
        print(f"Response: {json.dumps(response_payload, indent=2)}")

    except Exception as e:
        print(f"Error invoking Lambda for {year}-{month:02d}: {str(e)}")

    # Add a delay between invocations to avoid throttling
    if month < 12:
        print("Waiting 1 second before next invocation...")
        time.sleep(1)

print(f"\nCompleted all Lambda invocations at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Starting Lambda invocations at 2025-04-21 04:00:00
#
# Invoking Lambda for 2023-01...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=01/yellow_tripdata_2023-01.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_138fe8a59294dc8052eb15680dbf70a20205ec1921bea3cdb354e57e286617a0\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-02...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=02/yellow_tripdata_2023-02.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_b48314fc47cc4fa89e174b4d4a371c7622126213efd227e23916464ace24b578\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-03...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=03/yellow_tripdata_2023-03.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_0882c318f20738e3ec1f656c58508d26e16a84c8b1f69c0075f4b23fb24f6501\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-04...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=04/yellow_tripdata_2023-04.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_878a111359a4d67a1c4508d2ad9842a011bd4a7bd86b6f4fee15115dfb5c7a72\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-05...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=05/yellow_tripdata_2023-05.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_64934f788b9cb76113710534452af87660d31012037a8a8489cab69a127353a4\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-06...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=06/yellow_tripdata_2023-06.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_44fbdb91e4396f3dc0347eb1692cd28d51ad656dd164d089932bb37688b742a8\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-07...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=07/yellow_tripdata_2023-07.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_4e61f1940a6df691014c148a190868a935b2ae6f01d1b7b8f950acec6b36020a\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-08...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=08/yellow_tripdata_2023-08.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_9d73c16452ac613b75f0bd1e7619a9567d1cfa33cc3733368366631f1aa272de\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-09...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=09/yellow_tripdata_2023-09.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_1c5174d43eecb26abc770a63d60d5ba4598750711c7ec48b82fbe155406f0353\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-10...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=10/yellow_tripdata_2023-10.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_e10195297249edaab0264659be22b41fc6c9c3e71686fb5bd8f8e23122656ef4\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-11...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=11/yellow_tripdata_2023-11.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_9a072e2a3fa521a5a2a0976eba095e3e2d9c7eb8dbc0f7efc48b4f55623b33b4\"}"
# }
# Waiting 1 second before next invocation...
#
# Invoking Lambda for 2023-12...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File uploaded to S3: s3://jkim27-etl-5b9d2da3-5f5d-4ab5-bda1-80307b8dc702/taxi/raw/year=2023/month=12/yellow_tripdata_2023-12.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_c627c4bf7d6e77db99b91343f70076967813bcaa0559f820e70bb2186218636a\"}"
# }
#
# Completed all Lambda invocations at 2025-04-21 04:01:22
